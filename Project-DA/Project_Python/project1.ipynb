# %%
#1
import numpy as np
list = np.array([1,2,3,4,5,6,7])
square = list*list
print(square)
# Out:
# [ 1  4  9 16 25 36 49]

# %%
#2
list = [10,20,33,46,54,60]
for i in list:
  if i % 5 == 0:
    continue
  if i % 3 == 0:
    print(i)
# Out:
# 33
# 54

# %%
#3
keys = ['Ten', 'Twenty', 'Thirty']
values = [10, 20, 30]
d = {}
for i in range(len(keys)):
    d[keys[i]] = values[i]

print(d)
# Out:
# {'Ten': 10, 'Twenty': 20, 'Thirty': 30}

# %%
#4
string = "unigap"
for i in range(len(string)):
  if i % 2 != 0:
    print(string[i])
# Out:
# n
# g
# p

# %%
#5
number = 15980348
reversed_number =int(str(number)[::-1])
print(reversed_number)
# Out:
# 84308951

# %%
#6
n = int(input("Nhập một số nguyên: "))
tong = 0
for i in range(5, n+1):
        tong += i
print(tong)
# Out:
# Nhập một số nguyên: 10
# 45

# %%
#8
bo_so_nguyen =np.array([1, 2, 3, 4])
lap_phuong = bo_so_nguyen**3
print(lap_phuong)
# Out:
# [ 1  8 27 64]
